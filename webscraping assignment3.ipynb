# %% [markdown]
# Write a python program to search for a smartphone

# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\deepak\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\deepak\anaconda3\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\deepak\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Requirement already satisfied: requests in c:\users\deepak\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepak\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepak\anaconda3\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\deepak\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\deepak\anaconda3\lib\site-packages (from requests) (1.26.7)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
page = requests.get("https://www.flipkart.com/search?q=smartphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY")
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css" rel="stylesheet"/><meta content="text/html; charset=utf-8" http-equiv="Content-type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="102988293558" property="fb:page_id"/><meta content="658873552,624500995,100000233612389" property="fb:admins"/><meta content="noodp" name="robots"/><link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/><link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/><meta content="website" property="og:type"/><meta content="Flipkart.com" name="og_site_name" property="og:site_name"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon"/><meta content="app" name="twitter:card"/><meta content="@flipkart" name="twitter:site"/><meta content="@flipkart" name="twitter:creator"/><meta content="Smartphone- Buy Products Online at Best Price in India - All Categories | Flipkart.com" name="twitter:title"/><meta content="Shop for electronics, apparels &amp; more using our Flipkart app Free shipping &amp; COD." name="twitter:description"/><meta content="in" name="twitter:app:country"/><meta content="Flipkart" name="al:ios:app_name"/><meta content="742044692" name="al:ios:app_store_id"/><meta content="Flipkart" name="twitter:app:name:iphone"/><meta content="742044692" name="twitter:app:id:iphone"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:iphone"/><meta content="Flipkart" name="twitter:app:name:ipad"/><meta content="742044692" name="twitter:app:id:ipad"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:ipad"/><meta content="Flipkart" name="twitter:app:name:googleplay"/><meta content="com.flipkart.android" name="twitter:app:id:googleplay"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:googleplay"/><style>#container {
# 			height: 100%;
# 		}</style><script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/runtime.6518de50.js"></script><script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/vendor.chunk.71d08140.js"></script><script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app_modules.chunk.8b510926.js"></script><script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app_common.chunk.059c5166.js"></script><script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app.chunk.df57f5ba.js"></script><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/Browse.chunk.8b36b4.css" rel="stylesheet"/><title>Smartphone- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title><meta content="Smartphone- Buy Products Online at Best Price in India - All Categories | Flipkart.com" name="og_title" property="og:title"/><meta content="Smartphone" name="Keywords"/> <meta content="Smartphone- Buy Products Online at Best Price in India. India's Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com" name="Description"/><meta content="Smartphone- Buy Products Online at Best Price in India. India's Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com" property="og:description"/> <meta content="noindex" name="robots"/> <meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01"/> <!--[if IE 9 ]>
# 	<script nonce="15970842630737787911">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]--><!--[if !IE]><!--><script nonce="15970842630737787911">if (/*@cc_on!@*/false) {
# 			window.browserVersion = 'IE10';
# 			document.documentElement.className += ' ie10';
# 		}</script><!--<![endif]--> <script nonce="15970842630737787911">;window.NREUM||(NREUM={});NREUM.init={distributed_tracing:{enabled:true},privacy:{cookies_enabled:true},ajax:{deny_list:["bam.eu01.nr-data.net"]}};
# 		window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(31),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(32),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v]("popstate",function(){i(0,U>1)},N(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+p])try{window.performance[h](m,o,!1)}catch(t){}else try{window.performance[h]("webkit"+m,o,!1)}catch(t){}}function i(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(14),f=t(13),u=t(6),d=t(23),p="learResourceTimings",l="addEventListener",h="removeEventListener",m="resourcetimingbufferfull",v="bstResource",w="resource",g="-start",y="-end",x="fn"+g,b="fn"+y,E="bstTimer",R="pushState",O=t("loader");if(!O.disabled){O.features.stn=!0,t(9),"addEventListener"in window&&t(7);var T=NREUM.o.EV;a.on(x,function(t,e){var n=t[0];n instanceof T&&(this.bstStart=O.now())}),a.on(b,function(t,e){var n=t[0];n instanceof T&&s("bst",[n,e,this.bstStart,O.now()])}),c.on(x,function(t,e,n){this.bstStart=O.now(),this ...
# 		;NREUM.loader_config={accountID:"3370101",trustKey:"3293794",agentID:"491302072",licenseKey:"NRJS-2b21cef8f3d8d79db59",applicationID:"491285588"}
# 		;NREUM.info={beacon:"bam.eu01.nr-data.net",errorBeacon:"bam.eu01.nr-data.net",licenseKey:"NRJS-2b21cef8f3d8d79db59",applicationID:"491285588",sa:1};if(window.newrelic){if(window.newrelic.addRelease){window.newrelic.addRelease("fk-cp-zion", "4.109.4")}if(window.newrelic.setCurrentRouteName){window.newrelic.setCurrentRouteName("Search")}if(window.newrelic.setCustomAttribute){window.newrelic.setCustomAttribute("releaseId","4.109.4");window.newrelic.setCustomAttribute("deviceId", "TI166213976162600082544116559492868639168811491506068637082210926170");}}</script> <link href="https://www.flipkart.com/search?q=smartphone&amp;otracker=search&amp;otracker1=search&amp;marketplace=FLIPKART&amp;as-show=on&amp;as=off&amp;as-pos=1&amp;as-type=HISTORY&amp;page=2" id="next-page-link-tag" rel="next"/><script nonce="15970842630737787911">!function(){if("PerformancePaintTiming" in window){var e=window.__perf={e:[]};e.o=new PerformanceObserver(function(n){e.e=e.e.concat(n.getEntries())});try{e.o.observe({entryTypes:["paint"]})}catch(e){}}}();
#
# 		if (requestAnimationFrame && performance && performance.mark) {
# 			requestAnimationFrame(function () {
# 				window.first_paint = performance.now();
# 				performance.mark("first_paint");
# 			});
# 		}
#
#         // web-vitals polyfill for FID
#         !function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);</script></head><body><div id="container"><div><div class="_1kfTjk"><div class="_1rH5Jn"><div class="_1TmfNK"></div><div class="_2Xfa2_"><div class="_3_C9Hx"><div class="_3qX0zy"><a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="_1cmsER"><form action="/search" class="_2M8cLY header-form-search" method="GET"><div class="col-12-12 _2oO9oE"><div class="_3OO5Xc"><input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value="smartphone"/></div><button class="L0Z3Pu" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg"><g fill="#2874F1" fill-rule="evenodd"><path class="_34RNph" d="m11.618 9.897l4.225 4.212c.092.092.101.232.02.313l-1.465 1.46c-.081.081-.221.072-.314-.02l-4.216-4.203"></path><path class="_34RNph" d="m6.486 10.901c-2.42 0-4.381-1.956-4.381-4.368 0-2.413 1.961-4.369 4.381-4.369 2.42 0 4.381 1.956 4.381 4.369 0 2.413-1.961 4.368-4.381 4.368m0-10.835c-3.582 0-6.486 2.895-6.486 6.467 0 3.572 2.904 6.467 6.486 6.467 3.582 0 6.486-2.895 6.486-6.467 0-3.572-2.904-6.467-6.486-6.467"></path></g></svg></button><input name="otracker" type="hidden" value="search"/><input name="otracker1" type="hidden" value="search"/><input name="marketplace" type="hidden" value="FLIPKART"/><input name="as-show" type="hidden" value="off"/><input name="as" type="hidden" value="off"/></div><ul class="col-12-12 _1MRYA1"></ul></form></div><div class="go_DOp _2errNR"><div class="_28p97w"><div class="_1psGvi _3BvnxG"><div><a class="_1_3w1N" href="/account/login?ret=/search%3Fq%3Dsmartphone%26otracker%3Dsearch%26otracker1%3Dsearch%26marketplace%3DFLIPKART%26as-show%3Don%26as%3Doff%26as-pos%3D1%26as-type%3DHISTORY">Login</a></div></div></div></div><div class="go_DOp"><a class="_3-PJz-" href="https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span>Become a Seller</span></a></div><div class="go_DOp"><div class="_28p97w"><div class="_1psGvi _3BvnxG"><div><div class="exehdJ"> <!-- -->More<!-- --> </div></div></div><svg class="zZ3yfL" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg"><path class="_2gTTdy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div></div><div class="go_DOp"><div class="_1psGvi"><div class="YUhWwv"><a class="_3SkBxJ" href="/viewcart?exploreMode=true&amp;preference=FLIPKART"><svg class="V3C5bO" height="14" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg"><path class="_1bS9ic" d="M15.32 2.405H4.887C3 2.405 2.46.805 2.46.805L2.257.21C2.208.085 2.083 0 1.946 0H.336C.1 0-.064.24.024.46l.644 1.945L3.11 9.767c.047.137.175.23.32.23h8.418l-.493 1.958H3.768l.002.003c-.017 0-.033-.003-.05-.003-1.06 0-1.92.86-1.92 1.92s.86 1.92 1.92 1.92c.99 0 1.805-.75 1.91-1.712l5.55.076c.12.922.91 1.636 1.867 1.636 1.04 0 1.885-.844 1.885-1.885 0-.866- ...
# <p> Buildings Alyssa, Begonia &amp; </p>
# <p> Clove Embassy Tech Village, </p>
# <p> Outer Ring Road, Devarabeesanahalli Village, </p>
# <p> Bengaluru, 560103, </p>
# <p> Karnataka, India</p>
# </div></div></div></div></div><div class="_2Brcj4 address"><div class="_3IT4e6"><div class="_3-dnWo"><span>Registered Office Address:</span></div><div class="_1U1qnR"><div class="_1LJS6T"><div class="_2NKhZn _1U1qnR"><p>Flipkart Internet Private Limited, </p>
# <p> Buildings Alyssa, Begonia &amp; </p>
# <p> Clove Embassy Tech Village, </p>
# <p> Outer Ring Road, Devarabeesanahalli Village, </p>
# <p> Bengaluru, 560103, </p>
# <p> Karnataka, India </p>
# <p> CIN : U51109KA2012PTC066107 </p>
# <p> Telephone: <a href="tel:18002029898">044-45614700</a></p>
# </div></div></div></div></div></div><div><div class="_2uz0vJ"><div><img src="data:image/svg+xml;base64,..."/><a href="https://seller.flipkart.com/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span class="hDTmm5">Become a Seller</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="https://brands.flipkart.com"><span class="hDTmm5">Advertise</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="/the-gift-card-store?otracker=undefined_footer_footer_navlinks"><span class="hDTmm5">Gift Cards</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="/helpcentre?otracker=undefined_footer_footer_navlinks"><span class="hDTmm5">Help Center</span></a></div><span class="z3ht-w">© 2007-<!-- -->2022<!-- --> <span>Flipkart.com</span></span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/payment-method_69e7ec.svg"/></div></div></div></div></footer><div class="_1EcK2J _38JCdA"><div class="bra6U8"><svg class="_2TdLiZ" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="_3ZKfA2" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg><span>Back to top</span></div></div></div></div> <script id="jsonLD" nonce="15970842630737787911" type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.flipkart.com/samsung-galaxy-f22-denim-black-64-gb/p/itm6f47a19cb79ae?pid=MOBG43UGC3PYCBZF&lid=LSTMOBG43UGC3PYCBZFSIRYTE&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io","name":"SAMSUNG Galaxy F22 (Denim Black, 64 GB)"},{"@type":"ListItem","position":2,"url":"https://www.flipkart.com/samsung-galaxy-f22-denim-blue-64-gb/p/itmce0a6baf0d54d?pid=MOBG43UGBTGGB99V&lid=LSTMOBG43UGBTGGB99VLZACSD&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io","name":"SAMSUNG Galaxy F22 (Denim Blue, 64 GB)"},{"@type":"ListItem","position":3,"url":"https://www.flipkart.com/samsung-galaxy-f22-denim-blue-128-gb/p/itm30c755943bea0?pid=MOBG43UGRSMJXTMH&lid=LSTMOBG43UGRSMJXTMH8AUDHE&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io","name":"SAMSUNG Galaxy F22 (Denim Blue, 128 GB)"},{"@type":"ListItem","position":4,"url":"https://www.flipkart.com/realme-c21y-cross-blue-32-gb/p/itm2a2e4f7554a21?pid=MOBG5ZGKXCGFB9HP&lid=LSTMOBG5ZGKXCGFB9HPV9WVWE&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io","name":"realme C21Y (Cross Blue, 32 GB)"},{"@type":"ListItem","position":5,"url":"https://www.flipkart.com/realme-c21y-cross-black-64-gb/p/itm2a2e4f7554a21?pid=MOBG5ZGKQVSRBYGJ&lid=LSTMOBG5ZGKQVSRBYGJZFAT5X&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io","name":"realme C21Y (Cross Black, 64 GB)"},{"@type":"ListItem","position":6,"url":"https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSUPVRTR&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io","name":"APPLE iPhone 11 (White, 128 GB)"},{"@type":"ListItem","position":7,"url":"https://www.flipkart.com/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io","name":"APPLE iPhone 11 (White, 64 GB)"},{"@type":"ListItem","position":8,"url":"https://www.flipkart.com/realme-c11-2021-cool-grey-32-gb/p/itmbd856acb97c38?pid=MOBG4BEGX8QYNKGZ&lid=LSTMOBG4BEGX8QYNKGZ8JGQTA&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io","name":"realme C11 2021 (Cool Grey, 32 GB)"},{"@type":"ListItem","position":9,"url":"https://www.flipkart.com/realme-c11-2021-cool-grey-64-gb/p/itmbd856acb97c38?pid=MOBG5BCDJ68N57TH&lid=LSTMOBG5BCDJ68N57THWJHNPW&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io","name":"realme C11 2021 (Cool Grey, 64 GB)"},{"@type":"ListItem","position":10,"url":"https://www.flipkart.com/realme-c11-2021-cool-blue-32-gb/p/itmbd856acb97c38?pid=MOBG4BEG3HG78BDG&lid=LSTMOBG4BEG3HG78BDGXS0TYG&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io","name":"realme C11 202 ...
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.flipkart.com/",
#     "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "http://www.flipkart.com/search?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#         },{
#         "@type": "SearchAction",
#         "target": "android-app://com.flipkart.android/flipkart/de_sq_seg_-search.flipkart.com-_{search_term_string}",
#         "query-input": "required name=search_term_string"
#     }]
# }</script><script id="is_script" nonce="15970842630737787911">window.__INITIAL_STATE__ = {"abExperiments":{"computeBestSellerTagFromSocialProof":{"value":false,"abId":"051104b6","expId":"GH | Android Login - Control July 2022"},"isSpotlightEnabledCheckout":{"value":false,"abId":"051104b6","expId":"GH | Android Login - Control July 2022"},"isSpotlightEnabledCart":{"value":false,"abId":"051104b6","expId":"GH | Android Login - Control July 2022"},"enableSingleSLAForSamePrice":{"value":true,"abId":"2d2c899c","expId":"GH | Cart/CO | Single Delivery SLAs"},"groce-categ-6b957":{"value":"groce-categ-03e66","abId":"3c53448d","expId":"MGDAB 15thJuly 2022"},"homep-homep-7bb3a":{"value":"mgdse-homep-e6047","abId":"3c53448d","expId":"MGDAB 15thJuly 2022"},"homep-homep-ecfdf":{"value":"mgdse-homep-b1454","abId":"3c53448d","expId":"MGDAB 15thJuly 2022"},"groce-categ-c3296":{"value":"clone-categ-fb83f","abId":"3c53448d","expId":"MGDAB 15thJuly 2022"},"cartt-dynam-037fb":{"value":"clone-dynam-f6340","abId":"3d5e7fe9","expId":"Reco in empty cart"},"Header.X-PCD-CART-EMPTY":{"value":true,"abId":"3d5e7fe9","expId":"Reco in empty cart"},"pla_pctr_experiment1":{"value":"pla_pctr_ab","abId":"66501b88","expId":"p13nof10gmv"},"pla_pcvr_experiment1":{"value":"pla_pcvr_ab","abId":"66501b88","expId":"p13nof10gmv"},"p13nof10gmv":{"value":true,"abId":"66501b88","expId":"p13nof10gmv"},"perimeterXBlock":{"value":true,"abId":"6884aee4","expId":"Test - PerimeterX LogIn flow [2]"},"captcha_v4_on_ios":{"value":2,"abId":"7b92d7a3","expId":"Payment Page Test Mods"},"SC_PAY":{"value":2,"abId":"7b92d7a3","expId":"Payment Page Test Mods"},"estrellaFK.AB.enable":{"value":true,"abId":"7f99bdae","expId":"Estrella FK Marketplace Test Bucket"},"homepageBannerImprovmentExperiment":{"value":true,"abId":"d33448e4","expId":"Desktop HP LCP reduction V1_test"},"collapseFreebies":{"value":true,"abId":"e943c1bb","expId":"GH | Cart/CO - Collapse Freebies Widget"},"bucket[]":{"value":"sg_expt","abId":"ee2d9411","expId":"selection_gap_no_ctr_check_grocery_17_aug"},"rankingBucket":{"value":"new_nymeria_ab_1st_sep","abId":"fa3fd96a","expId":"Nymeria_1st_sep"},"super-dynam-0517b":{"value":"clone-dynam-c5465","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"testVar":{"value":"control","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"disco-dynam-cbb72":{"value":"disco-dynam-cbb72","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"super-dynam-35f69":{"value":"clone-dynam-b4918","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"clone-dynam-1c690":{"value":"clone-dynam-1c690","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"super-dynam-2ae24":{"value":"clone-dynam-84f57","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"clone-dynam-84f57":{"value":"clone-dynam-84f57","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"clone-dynam-c5465":{"value":"clone-dynam-c5465","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"super-dynam-70d21":{"value":"clone-dynam-1c690","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"super-dynam-ed52e":{"value":"clone-dynam-771ca","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"clone-dynam-771ca":{"value":"clone-dynam-771ca","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"},"clone-dynam-b4918":{"value":"clone-dynam-b4918","abId":"STG|1embENZcs6GuTrfadPCTKG","expId":"scz_gamification_weekly_puzzle"}},"activateVip":{"asyncStatus":"INIT","widget":[]},"autosuggest":{"query":null,"payloadId":null,"searchHistory":[],"asyncStatus":"INIT","words":{},"searchBrowseHistoryRequest":{}},"basket":{"asyncStatus":"INIT","pageLevelError":false},"buyingGuides":{"asyncStatus":"INIT"},"cartData":{"asyncStatus":"INIT","pageLevelError":false},"saveForLaterData":{"asyncSt ...
# <link data-chunk="SearchFeedback" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/SearchFeedback.chunk.d0537a.css" rel="stylesheet"/> <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[119,190]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["NavMenu","SearchFeedback"]}</script>
# <script async="" data-chunk="NavMenu" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/NavMenu.chunk.8cc10166.js"></script>
# <script async="" data-chunk="SearchFeedback" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/SearchFeedback.chunk.41ccf523.js"></script><script nonce="15970842630737787911">window.omniture={tpv:[],tl:[]};window.omniture.trackPageView=function(){window.omniture.tpv.push(arguments)};window.omniture.trackLink=function(){window.omniture.tl.push(arguments)}
#
#     if(window.location.host === 'www.flipkart.com' || /\.store\.flipkart\.com/i.test(window.location.host)){
#         window.s_account = "flipkart-prd"; //omniture account id
#     }else{
#         window.s_account = "flipkart-prd-test";
#     }
#     window.s_isDesktop = true;</script><script nonce="15970842630737787911">if ('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") === -1) {
# 		navigator.serviceWorker.register('/sw.js').then(function(registration) {
# 			console.log('ServiceWorker registration successful with scope: ', registration.scope);
# 			navigator.onLine && navigator.serviceWorker.controller && navigator.serviceWorker.controller.postMessage('BANDWIDTH_COMPUTE');
# 			navigator.serviceWorker.addEventListener('message', function (event) {
# 				try {
# 					const bandwidthData = JSON.parse(event.data);
# 					if (bandwidthData && bandwidthData.data) {
# 						window.bandwidth = bandwidthData.data.downlink + '_' + bandwidthData.data.computeMethod + '_' + bandwidthData.data.effectiveType + '_' + bandwidthData.data.type;
# 					}
# 				}catch(err) {
# 					console.error('JSON.parse failed:', err);
# 				}
# 			});
# 		})
# 		.catch(function(err) {
# 			console.error('ServiceWorker registration failed: ', err);
# 		});
# 	} else if('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") > -1){
#         navigator.serviceWorker.getRegistration().then(function(registration) {
#             var serviceWorkerUnregistered=false;
#             if(registration) {
#                 registration.unregister();
#                 serviceWorkerUnregistered=true;
#             }
#             serviceWorkerUnregistered && window.location.reload();
#         });
#     }</script><script async="" defer="defer" id="omni_script" nonce="15970842630737787911" src="//static-assets-web.flixcart.com/www/linchpin/batman-returns/omni/omni16.js"></script> <script nonce="15970842630737787911">window._pxAppId = 'PXgNtTli3A';</script><script async="" nonce="15970842630737787911" src="//static-assets-web.flixcart.com/px/gNtTli3A/init.js"></script></body></html>

# %%
brand_name = soup.find_all('div',class_="_4rR01T")
brand_name[:24]
# Out:
# [<div class="_4rR01T">SAMSUNG Galaxy F22 (Denim Black, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F22 (Denim Blue, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F22 (Denim Blue, 128 GB)</div>,
#  <div class="_4rR01T">realme C21Y (Cross Blue, 32 GB)</div>,
#  <div class="_4rR01T">realme C21Y (Cross Black, 64 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 11 (White, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 11 (White, 64 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Grey, 32 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Grey, 64 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Blue, 32 GB)</div>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Champagne Gold, 64 GB)</div>,
#  <div class="_4rR01T">realme C21Y (Cross Black, 32 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 11 (Black, 128 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Blue, 64 GB)</div>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Horizon Blue, 64 GB)</div>,
#  <div class="_4rR01T">realme 8i (Space Purple, 64 GB)</div>,
#  <div class="_4rR01T">realme C21Y (Cross Blue, 64 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 11 (Black, 64 GB)</div>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Daylight Green, 64 GB)</div>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Racing Black, 64 GB)</div>,
#  <div class="_4rR01T">REDMI Note 11 SE (Without Charger) (Thunder Purple, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)</div>,
#  <div class="_4rR01T">realme 8s 5G (Universe Blue, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Midnight, 128 GB)</div>]

# %%
for item in brand_name:
    print(item.text)
# Out:
# SAMSUNG Galaxy F22 (Denim Black, 64 GB)
# SAMSUNG Galaxy F22 (Denim Blue, 64 GB)
# SAMSUNG Galaxy F22 (Denim Blue, 128 GB)
# realme C21Y (Cross Blue, 32 GB)
# realme C21Y (Cross Black, 64 GB)
# APPLE iPhone 11 (White, 128 GB)
# APPLE iPhone 11 (White, 64 GB)
# realme C11 2021 (Cool Grey, 32 GB)
# realme C11 2021 (Cool Grey, 64 GB)
# realme C11 2021 (Cool Blue, 32 GB)
# Infinix HOT 12 Play (Champagne Gold, 64 GB)
# realme C21Y (Cross Black, 32 GB)
# APPLE iPhone 11 (Black, 128 GB)
# realme C11 2021 (Cool Blue, 64 GB)
# Infinix HOT 12 Play (Horizon Blue, 64 GB)
# realme 8i (Space Purple, 64 GB)
# realme C21Y (Cross Blue, 64 GB)
# APPLE iPhone 11 (Black, 64 GB)
# Infinix HOT 12 Play (Daylight Green, 64 GB)
# Infinix HOT 12 Play (Racing Black, 64 GB)
# REDMI Note 11 SE (Without Charger) (Thunder Purple, 64 GB)
# SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)
# realme 8s 5G (Universe Blue, 128 GB)
# APPLE iPhone 13 (Midnight, 128 GB)

# %%
price=soup.find_all('div',class_="_30jeq3 _1_WHN1")
price[:24]
# Out:
# [<div class="_30jeq3 _1_WHN1">₹10,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,599</div>,
#  <div class="_30jeq3 _1_WHN1">₹54,900</div>,
#  <div class="_30jeq3 _1_WHN1">₹41,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹54,900</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,049</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,599</div>,
#  <div class="_30jeq3 _1_WHN1">₹41,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹20,099</div>,
#  <div class="_30jeq3 _1_WHN1">₹69,999</div>]

# %%
for item in price:
    print(item.text)
# Out:
# ₹10,499
# ₹10,499
# ₹12,499
# ₹9,499
# ₹10,599
# ₹54,900
# ₹41,999
# ₹7,499
# ₹8,999
# ₹7,499
# ₹8,999
# ₹9,499
# ₹54,900
# ₹8,999
# ₹8,999
# ₹14,049
# ₹10,599
# ₹41,999
# ₹8,999
# ₹8,999
# ₹13,999
# ₹11,999
# ₹20,099
# ₹69,999

# %%
rating=soup.find_all('span',class_="_2_R_DZ")
rating[:24]
# Out:
# [<span class="_2_R_DZ"><span><span>84,408 Ratings </span><span class="_13vcmD">&amp;</span><span> 8,374 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>84,408 Ratings </span><span class="_13vcmD">&amp;</span><span> 8,374 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>53,507 Ratings </span><span class="_13vcmD">&amp;</span><span> 5,121 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>86,389 Ratings </span><span class="_13vcmD">&amp;</span><span> 2,986 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>2,43,484 Ratings </span><span class="_13vcmD">&amp;</span><span> 9,399 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>93,378 Ratings </span><span class="_13vcmD">&amp;</span><span> 6,954 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>93,378 Ratings </span><span class="_13vcmD">&amp;</span><span> 6,954 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>2,22,120 Ratings </span><span class="_13vcmD">&amp;</span><span> 9,830 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>1,95,476 Ratings </span><span class="_13vcmD">&amp;</span><span> 10,868 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>2,22,120 Ratings </span><span class="_13vcmD">&amp;</span><span> 9,830 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>47,861 Ratings </span><span class="_13vcmD">&amp;</span><span> 4,235 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>86,389 Ratings </span><span class="_13vcmD">&amp;</span><span> 2,986 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>93,378 Ratings </span><span class="_13vcmD">&amp;</span><span> 6,954 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>1,95,476 Ratings </span><span class="_13vcmD">&amp;</span><span> 10,868 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>47,861 Ratings </span><span class="_13vcmD">&amp;</span><span> 4,235 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>1,59,669 Ratings </span><span class="_13vcmD">&amp;</span><span> 10,338 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>2,43,484 Ratings </span><span class="_13vcmD">&amp;</span><span> 9,399 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>93,378 Ratings </span><span class="_13vcmD">&amp;</span><span> 6,954 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>47,861 Ratings </span><span class="_13vcmD">&amp;</span><span> 4,235 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>47,861 Ratings </span><span class="_13vcmD">&amp;</span><span> 4,235 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>11,826 Ratings </span><span class="_13vcmD">&amp;</span><span> 745 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>50,533 Ratings </span><span class="_13vcmD">&amp;</span><span> 4,603 Reviews</span></span></span>,
#  <span class="_2_R_DZ"><span><span>10,059 Ratings </span><span class="_13vcmD">&amp;</span><span> 969 Reviews</span></span></span>]

# %%
for i in rating:
    print(item.text)
# Out:
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999
# ₹69,999

# %%
print(len(brand_name),len(price),len(rating))
# Out:
# 24 24 23

# %%
df=pd.DataFrame({'Brand':brand_name,'Price':price,'Rating':rating})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1920/63495973.py in <module>
# ----> 1 df=pd.DataFrame({'Brand':brand_name,'Price':price,'Rating':rating})
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# Python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user.

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\deepak\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\deepak\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\deepak\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\deepak\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: async-generator>=1.9 in c:\users\deepak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\deepak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\deepak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\deepak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: idna in c:\users\deepak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: outcome in c:\users\deepak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\deepak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\deepak\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\deepak\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\deepak\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\deepak\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\deepak\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\deepak\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: six>=1.5.2 in c:\users\deepak\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\deepak\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.amazon.in")

# %%
designation=driver.find_element(By.CLASS_NAME,"nav-search-field")
designation.send_keys=(input("Enter product to search = "))
# Out:
# Enter product to search = Guitar

# %%
search=driver.find_element(By.CLASS_NAME,"nav-right")
search.click()

# %%
Brand_name=[]
ratings=[]
prices=[]
delivery_time=[]

# %%
name_tags=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
for i in name_tags:
    name=i.text
    Brand_name.append(name)

# %%
ratings_tags=driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]')
for i in ratings_tags:
    rating=i.text
    ratings.append(rating)

# %%
prices_tags=driver.find_elements(By.XPATH,'//span[@class="a-offscreen"]')
for i in prices_tags:
    price=i.text
    prices.append(price)

# %%
time_tags=driver.find_elements(By.XPATH,'//span[@class="a-color-base a-text-bold"]')
for i in time_tags:
    time=i.text
    delivery_time.append(time)

# %%
print(len(Brand_name),len(ratings),len(prices),len(delivery_time))
# Out:
# 0 0 5 0

# %%
url=("https://www.amazon.in/s?k=Guitar&crid=FXNSEND6NX2Y&sprefix=guitar%2Caps%2C246&ref=nb_sb_noss_1")
url
# Out:
# 'https://www.amazon.in/s?k=Guitar&crid=FXNSEND6NX2Y&sprefix=guitar%2Caps%2C246&ref=nb_sb_noss_1'

# %%
df=pd.DataFrame({'Brand':Brand_name,'Ratings':ratings,'Price':prices,'Delivery':delivery_time})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1920/4148834658.py in <module>
# ----> 1 df=pd.DataFrame({'Brand':Brand_name,'Ratings':ratings,'Price':prices,'Delivery':delivery_time})
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://trak.in/india-startup-funding-investment-2015/")

# %%
january=[]
february=[]
march=[]

# %%
january_tags=driver.find_elements(By.XPATH,'//div[@class="dataTables_scroll"]')
for i in january_tags:
    jan=i.text
    january.append(jan)

# %%
february_tags=driver.find_elements(By.XPATH,'//div[@class="dataTables_scroll"]')
for i in february_tags:
    feb=i.text
    february.append(feb)

# %%
march_tags=driver.find_elements(By.XPATH,'//div[@class="dataTables_scroll"]')
for i in march_tags:
    mar=i.text
    march.append(mar)

# %%
print(len(january),len(february),len(march))
# Out:
# 45 45 45

# %%
df=pd.DataFrame({'JAN2021':january,'FEB2021':february,'MAR2021':march})
df
# Out:
#                                               JAN2021  \
# 0   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 1   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 2   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 3   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 4   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 5   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 6   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 7   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 8   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 9   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 10  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 11  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 12  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 13  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 14  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 15  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 16  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 17  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 18  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 19  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 20  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 21  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 22  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 23  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 24  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 25  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 26  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 27  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 28  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 29  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 30  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 31  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 32  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 33  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 34  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 35  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 36  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 37  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 38  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 39  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 40  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 41  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 42  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 43  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 44  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
#
#                                               FEB2021  \
# 0   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 1   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 2   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 3   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 4   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 5   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 6   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 7   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 8   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 9   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 10  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 11  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 12  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 13  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 14  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 15  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 16  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 17  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 18  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 19  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 20  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 21  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 22  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 23  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 24  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 25  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 26  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 27  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 28  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 29  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 30  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 31  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 32  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 33  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 34  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 35  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 36  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 37  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 38  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 39  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 40  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 41  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 42  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 43  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 44  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
#
#                                               MAR2021
# 0   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 1   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 2   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 3   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 4   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 5   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 6   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 7   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 8   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 9   Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 10  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 11  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 12  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 13  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 14  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 15  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 16  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 17  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 18  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 19  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 20  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 21  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 22  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 23  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 24  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 25  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 26  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 27  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 28  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 29  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 30  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 31  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 32  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 33  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 34  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 35  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 36  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 37  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 38  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 39  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 40  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 41  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 42  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 43  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...
# 44  Sr. No. Date (dd/mm/yyyy) Startup Name Industr...

# %% [markdown]
# Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.webdriver.common.by import By

# %%
driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")

# %%
laptop_gaming=[]
company_laptop=[]
price=[]

# %%
laptop_tags=driver.find_elements(By.XPATH,'//td[@class="MSI Titan GT77-12UHS"]')
for i in laptop_tags:
    laptop=i.text
    laptop_gaming.append(laptop)

# %%
company_tags=driver.find_elements(By.XPATH,'//td[@class="smmerchant"]')
for i in company_tags:
    company=i.text
    company_laptop.append(company)

# %%
price_tags=driver.find_elements(By.XPATH,'//td[@class="smprice"]')
for i in price_tags:
    rates=i.text
    price.append(rates)

# %%
print(len(laptop_gaming),len(company_laptop),len(price))
# Out:
# 0 10 10

# %%
df=pd.DataFrame({"GAMING LAPTOP":laptop_gaming,'SELLER':company_laptop,'PRICE':price})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1920/96564240.py in <module>
# ----> 1 df=pd.DataFrame({"GAMING LAPTOP":laptop_gaming,'SELLER':company_laptop,'PRICE':price})
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# SCrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver.get("https://www.forbes.com/billionaires/")

# %%
billrank=[]
billname=[]
billworth=[]
billage=[]
billcitizenship=[]
billsource=[]
billindustry=[]

# %%
billrank_tags=driver.find_elements(By.XPATH,'//div[@class="rank"]')
for i in billrank_tags:
    rank=i.text
    billrank.append(rank)

# %%
billname_tags=driver.find_elements(By.XPATH,'//div[@class="personName"]')
for i in billname_tags:
    name=i.text
    billname.append(name)

# %%
billworth_tags=driver.find_elements(By.XPATH,'//div[@class="netWorth"]')
for i in billworth_tags:
    worth=i.text
    billworth.append(worth)

# %%
billage_tags=driver.find_elements(By.XPATH,'//div[@class="age"]')
for i in billage_tags:
    age=i.text
    billage.append(age)

# %%
billcitizenship_tags=driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
for i in billcitizenship_tags:
    citizenship=i.text
    billcitizenship.append(citizenship)

# %%
billsource_tags=driver.find_elements(By.XPATH,'//div[@class="source"]')
for i in billsource_tags:
    source=i.text
    billsource.append(source)

# %%
billindustry_tags=driver.find_elements(By.XPATH,'//div[@class="category"]')
for i in billindustry_tags:
    industry=i.text
    billindustry.append(industry)

# %%
print(len(billrank),len(billname),len(billworth),len(billage),len(billcitizenship),len(billsource),len(billindustry))
# Out:
# 200 200 200 200 200 200 200

# %%
df=pd.DataFrame({"RANK":billrank,"NAME":billname,"WORTH":billworth,"CITIZENSHIP":billcitizenship,"SOURCE":billsource,"INDUSTRY":billindustry})
df
# Out:
#      RANK                      NAME    WORTH    CITIZENSHIP  \
# 0      1.                 Elon Musk   $219 B  United States
# 1      2.                Jeff Bezos   $171 B  United States
# 2      3.  Bernard Arnault & family   $158 B         France
# 3      4.                Bill Gates   $129 B  United States
# 4      5.            Warren Buffett   $118 B  United States
# ..    ...                       ...      ...            ...
# 195  192.    Marcel Herrmann Telles  $10.3 B         Brazil
# 196  197.                Leon Black    $10 B  United States
# 197  197.                Joe Gebbia    $10 B  United States
# 198  197.              David Geffen    $10 B  United States
# 199  197.                Yu Renrong    $10 B          China
#
#                     SOURCE               INDUSTRY
# 0            Tesla, SpaceX             Automotive
# 1                   Amazon             Technology
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4       Berkshire Hathaway  Finance & Investments
# ..                     ...                    ...
# 195                   beer        Food & Beverage
# 196         private equity  Finance & Investments
# 197                 Airbnb             Technology
# 198  movies, record labels  Media & Entertainment
# 199         semiconductors          Manufacturing
#
# [200 rows x 6 columns]

# %% [markdown]
# Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video

# %%
driver.get("https://www.youtube.com/watch?v=BddP6PYo2gs&list=RDCLAK5uy_n9Fbdw7e6ap-98_A-8JYBmPv64v-Uaq1g")

# %%
videocomment=[]
videoupvote=[]
videotime=[]

# %%
videocomment_tags=driver.find_elements(By.XPATH,'//div[@class="style-scope ytd-expander"]')
for i in videocomment_tags:
    comment=i.text
    videocomment.append(comment)

# %%
videoupvote_tags=driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope ytd-toggle-button-renderer"]')
for i in videoupvote_tags:
    upvote=i.text
    videoupvote.append(upvote)

# %%
videotime_tags=driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
for i in videotime_tags:
    time=i.text
    videotime.append(time)

# %%
print(len(videocomment),len(videoupvote),len(videotime))
# Out:
# 2 3 47

# %%
df=pd.DataFrame({"COMMENT":videocomment,"UPVOTE":videoupvote,"TIME":videotime})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1920/1228753003.py in <module>
# ----> 1 df=pd.DataFrame({"COMMENT":videocomment,"UPVOTE":videoupvote,"TIME":videotime})
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,overall reviews, privates from price, dorms from price, facilities and property description

# %%
driver.get("https://www.hostelworld.com/")

# %%
location=driver.find_element(By.CLASS_NAME,"location-text")
location.send_keys("London")

# %%
search=driver.find_element(By.CLASS_NAME,"search-button")
search.click()

# %%
hostelname=[]
distancefromcity=[]
hostelrating=[]
totalreview=[]
hostelprice=[]
dormsprice=[]
propertydiscussion=[]

# %%
hostelname_tags=driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
for i in hostelname_tags:
    name=i.text
    hostelname.append(name)

# %%
distancefromcity_tags=driver.find_elements(By.XPATH,'//div[@class="subtitle body-3"]')
for i in distancefromcity_tags:
    distance=i.text
    distancefromcity.append(distance)

# %%
hostelrating_tags=driver.find_elements(By.XPATH,'//div[@class="score orange big"]')
for i in hostelrating_tags:
    rating=i.text
    hostelrating.append(rating)

# %%
totalreview_tags=driver.find_elements(By.XPATH,'//div[@class="reviews"]')
for i in totalreview_tags:
    review=i.text
    totalreview.append(review)

# %%
hostelprice_tags=driver.find_elements(By.XPATH,'//div[@class="price title-5"]')
for i in hostelprice_tags:
    price=i.text
    hostelprice.append(price)

# %%
dormsprice_tags=driver.find_elements(By.XPATH,'//div[@class="price-col"]')
for i in dormsprice_tags:
    dprice=i.text
    dormsprice.append(dprice)

# %%
propertydiscussion_tags=driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
for i in propertydiscussion_tags:
    discussion=i.text
    propertydiscussion.append(discussion)

# %%
print(len(hostelname),len(distancefromcity),len(hostelrating),len(totalreview),len(hostelprice),len(dormsprice),len(propertydiscussion))
# Out:
# 0 0 0 0 0 0 0

# %%
df=pd.DataFrame({"NAME":hostelname,"DISTANCE":distancefromcity,"RATING":hostelrating,"REVIEW":totalreview,"PRICE":hostelprice,"DORMS":dormsprice,"PROPERTY":propertydiscussion})
df
# Out:
# Empty DataFrame
# Columns: [NAME, DISTANCE, RATING, REVIEW, PRICE, DORMS, PROPERTY]
# Index: []
